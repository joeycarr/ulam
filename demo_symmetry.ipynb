# %%
import matplotlib.pyplot as plt
import numpy as np
import skimage

from skimage import data

# %%
# %matplotlib inline

# %%
from symmetry import *

# %%
img = data.chelsea()[:, -300:]
test = pinwheel(img)
plt.imshow(test)

# %%
plt.imshow(pinwheel(pinwheel(img)))

# %%
fig, ax = plt.subplots(1,3)
ax[0].imshow(twofoldh(img))
ax[1].imshow(twofoldv(img))
ax[2].imshow(fourfold(img))

# %%
fig, ax = plt.subplots(1,2)
ax[0].imshow(proph(img))
ax[1].imshow(propv(img))

# %%
fig, ax = plt.subplots(1,2)
ax[0].imshow(tile(glideh(img, img), rows=1))
ax[1].imshow(tile(glidev(img, img), cols=1))
